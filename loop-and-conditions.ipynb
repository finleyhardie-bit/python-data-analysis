# %%
##1

# %%
names = ["Alex", "Jamie", "Chris", "Taylor", "Jordan"]

# %%
names?
# Out:
# Type:        list
# String form: ['Alex', 'Jamie', 'Chris', 'Taylor', 'Jordan']
# Length:      5
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
print(names[0])
# Out:
# Alex

# %%
print(names[1])
# Out:
# Jamie

# %%
for i in range(len(names)):
    print(names[i])
# Out:
# Alex
# Jamie
# Chris
# Taylor
# Jordan

# %%
##2

# %%
import numpy as np

# %%
myArray = np.random.normal(100, 10, 100)

# %%
print(myArray[:30])
# Out:
# [110.00433948  88.35213184 112.89769526 110.87724884  95.52536648
#   86.22699642  90.22133688  91.47884884  95.65539501  84.73039357
#   92.89019668 104.95324614 105.40594267 108.65970618  91.85068817
#   99.69218774  97.9300615  107.05150157  98.74747707 104.90828332
#   90.49855767 110.32633354 101.14771324 107.19983627  94.41334788
#  108.92273567  87.10576002 105.21681358 111.59880986 102.91737653]

# %%
import pandas as pd

# %%
mydf = pd.DataFrame({
    "employees": [24, 15, 25, 30],
    "location": [13, 8, 4, 2],
    "sales": [34523, 12345, 39324, 41234]
}, index=["Dallas", "Austin", "Fort Worth", "Houston"])

# %%
##3

# %%
mydf
# Out:
#             employees  location  sales
# Dallas             24        13  34523
# Austin             15         8  12345
# Fort Worth         25         4  39324
# Houston            30         2  41234

# %%
mydf["employees"]
# Out:
# Dallas        24
# Austin        15
# Fort Worth    25
# Houston       30
# Name: employees, dtype: int64

# %%
mydf.loc["Dallas"]
# Out:
# employees       24
# location        13
# sales        34523
# Name: Dallas, dtype: int64

# %%
mydf.loc["Dallas", "sales"]
# Out:
# np.int64(34523)

# %%
mydf.loc["Dallas", ["sales", "employees"]]
# Out:
# sales        34523
# employees       24
# Name: Dallas, dtype: int64

# %%
mydf[mydf["sales"] > 35000]
# Out:
#             employees  location  sales
# Fort Worth         25         4  39324
# Houston            30         2  41234

# %%
##4

# %%
dfIC = pd.read_csv("IceCreamData.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 dfIC = pd.read_csv("IceCreamData.csv")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...
